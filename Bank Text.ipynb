# %%
import glob, nltk
from nltk.tokenize import word_tokenize
import re
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Ariel Karlinsky\\Google Drive\\Financial Regulation\\Ariel\\Text Analysis\\Programs'

# %%
#textfiles = glob.glob("C:/Users/Danny/Desktop/TEXTFILES/*.txt")
textfiles = glob.glob("../Data/*.txt")
len(textfiles)
# Out:
# 254

# %%
file = open(textfiles[1],encoding="utf8")
text = file.read()

# %%
onegram = list(nltk.ngrams(nltk.word_tokenize(text),n=1))
bigram = list(nltk.bigrams(nltk.word_tokenize(text)))
trigram = list(nltk.trigrams(nltk.word_tokenize(text)))
tokens = nltk.word_tokenize(" ".join(text))
raw = ', '.join(' '.join((a, b)) for a, b in bigram)
def remove_punct(text):
    return re.compile(r"[^\d\W]+").findall(text)

# %%
from collections import Counter
a= remove_punct(" ".join(map(str, bigram)))
a= [word for word in a if len(word) >2]
Counter(a).most_common(30)
# Out:
# [('הבנקים', 45),
#  ('האשראי', 24),
#  ('ההון', 22),
#  ('הבנקאות', 20),
#  ('זאת', 14),
#  ('בישראל', 14),
#  ('מספר', 12),
#  ('בשנים', 12),
#  ('האחרונות', 12),
#  ('מערכת', 12),
#  ('יחס', 12),
#  ('העלייה', 10),
#  ('השנה', 9),
#  ('פעילות', 8),
#  ('הון', 8),
#  ('בשנת', 8),
#  ('להון', 8),
#  ('הישראלית', 8),
#  ('בין', 8),
#  ('לבנקים', 8),
#  ('בנקאות', 8),
#  ('תחומי', 8),
#  ('עלייה', 6),
#  ('הפעילות', 6),
#  ('הקבוצות', 6),
#  ('במדינות', 6),
#  ('ההפרשות', 6),
#  ('לחובות', 6),
#  ('מסופקים', 6),
#  ('ברוב', 6)]

# %%
w = [word for word in text.split() if len(word) >1]

# %%
tokens = [word_tokenize(word) for word in w]
"".join(str(token) for token in tokens)
# Out:
# '[\'השנה\'][\'הנסקרת\'][\'מאופיינת\'][\'בהתרחבות\'][\'ניכרת\'][\'של\'][\'פעילות\'][\'הבנקים\', \',\'][\'שהתבטאה\'][\'בעלייה\'][\'בת\'][\'13\', \'%\'][\'של\'][\'מיצרף\'][\'האשראי\'][\'ובעלייה\'][\'בת\'][\'10.5\', \'%\'][\'של\'][\'סך\'][\'פיקדונות\'][\'הציבור\'][\'בבנקים\', \'.\'][\'לגידול\'][\'האשראי\'][\'תרמו\'][\'מספר\'][\'גורמים\'][\'עלייה\'][\'בשימושים\', \',\'][\'ובעיקר\'][\'בשימושים\'][\'עתירי\'][\'האשראי\'][\'כהשקעות\'][\'ויצוא\', \',\'][\'התאוששות\'][\'התוצר\'][\'במחצית\'][\'השנייה\'][\'של\'][\'השנה\', \',\'][\'עלייה\'][\'בצורכי\'][\'המימון\'][\'של\'][\'הון\'][\'חוזר\'][\'ומלאים\', \',\'][\'מימון\'][\'רכישה\'][\'של\'][\'חברות\'][\'ועלייה\'][\'במימון\'][\'של\'][\'פעילות\'][\'לווים\'][\'בחו\', "\'\'", \'ל\', \'.\'][\'גידול\'][\'הפעילות\'][\'הבנקאית\'][\'בשנת\'][\'1999\'][\'התבטא\'][\'בהמשך\'][\'העלייה\'][\'ברווח\'][\'ובתשואה\'][\'להון\', \',\'][\'וזאת\'][\'על\'][\'אף\'][\'ההאטה\'][\'בפעילות\'][\'המשקית\'][\'בשנים\'][\'האחרונות\', \'.\'][\'התשואה\'][\'להון\'][\'שהשיגו\'][\'חמש\'][\'הקבוצות\'][\'הבנקאיות\'][\'הגדולות\'][\'הגיעה\'][\'השנה\'][\'לכ-\'][\'11.2\', \'%\'][\'מעל\'][\'לממוצע\'][\'הרב-שנתי\'][\'של\'][\'העשור\'][\'האחרון\', \'.\'][\'עם\'][\'זאת\'][\'ביצועיה\'][\'של\'][\'מערכת\'][\'הבנקאות\'][\'הישראלית\'][\'אינם\'][\'חורגים\'][\'מהמקובל\'][\'בענף\'][\'זה\'][\'בעולם\', \';\'][\'כך\', \',\'][\'למשל\', \',\'][\'התשואה\'][\'להון\'][\'והמירווח\'][\'הפיננסי\'][\'שהשיגו\'][\'הקבוצות\'][\'הבנקאיות\'][\'דומים\'][\'לממוצע\'][\'במדינות\'][\'מערביות\'][\'בנות\'][\'השוואה\'][\'לישראל\', \'.\'][\'לגידול\'][\'הרווחים\'][\'בשנת\'][\'1999\'][\'תרמו\'][\'בעיקר\'][\'העלייה\'][\'ברווחי\'][\'המימון\', \',\'][\'שנבעה\'][\'מהתרחבות\'][\'הפעילות\'][\'בכל\'][\'אחד\'][\'ממגזרי\'][\'ההצמדה\', \',\'][\'לצד\'][\'יציבות\'][\'במירווח\'][\'הפיננסי\'][\'הכולל\', \'.\'][\'כן\'][\'היינו\'][\'עדים\'][\'השנה\'][\'לירידת\'][\'ההפרשות\'][\'לחובות\'][\'מסופקים\'][\'ברוב\'][\'ענפי\'][\'המשק\'][\'למרות\'][\'ההאטה\'][\'הכלכלית\', \',\'][\'המשפיעה\'][\'לרעה\'][\'על\'][\'איכות\'][\'האשראי\', \'.\'][\'שיעור\'][\'ההפרשות\'][\'לחובות\'][\'מסופקים\'][\'מהאשראי\'][\'לציבור\'][\'שבאחריות\'][\'הקבוצות\'][\'הולך\'][\'ויורד\'][\'בשנים\'][\'האחרונות\', \',\'][\'והשנה\'][\'הוא\'][\'הגיע\'][\'לכ-\'][\'0.5\', \'%\'][\'בלבד\', \'.\'][\'שיעורי\'][\'ההפרשה\'][\'בישראל\'][\'נמוכים\'][\'במקצת\'][\'מהממוצע\'][\'במדינות\'][\'בנות\'][\'השוואה\', \'.\'][\'ברקע\'][\'הדברים\'][\'חשוב\'][\'להדגיש\'][\'כי\'][\'בשנה\'][\'הנסקרת\'][\'גדלה\'][\'חשיפתם\'][\'של\'][\'הבנקים\'][\'לסיכוני\'][\'אשראי\', \',\'][\'בגלל\'][\'הגידול\'][\'הניכר\'][\'של\'][\'היקף\'][\'האשראי\'][\')\', \'גם\'][\'ביחס\'][\'להון\'][\'הבנקים\', \'(\', \',\'][\'העלייה\'][\'של\'][\'משקל\'][\'האשראי\'][\'הבעייתי\'][\'בסך\'][\'האשראי\', \',\'][\'ובפרט\'][\'העלייה\'][\'של\'][\'יחס\'][\'האשראי\'][\'לתוצר\'][\'ברוב\'][\'ענפי\'][\'המשק\', \'.\'][\'עליית\'][\'יחס\'][\'זה\'][\'מצביעה\'][\'על\'][\'ירידה\'][\'בכושר\'][\'הפירעון\'][\'של\'][\'הסקטור\'][\'העסקי\', \',\'][\'ובולטת\'][\'מאוד\'][\'בענף\'][\'הנדל\', "\'\'", \'ן\'][\'מצב\'][\'המגדיל\'][\'את\'][\'חשיפת\'][\'הבנקים\'][\'לסיכון\'][\'האשראי\', \'.\'][\'לפיכך\'][\'ייתכן\'][\'שרמת\'][\'ההפרשות\'][\'הספציפיות\'][\'לחובות\'][\'מסופקים\'][\'בשנת\'][\'1999\'][\'אינה\'][\'מעידה\'][\'על\'][\'רמת\'][\'הסיכון\'][\'של\'][\'הבנקים\'][\'בתיקי\'][\'האשראי\', \'.\'][\'לכן\'][\'על\'][\'הבנקים\'][\'לבחון\'][\'בקפידה\'][\'את\'][\'הנאותות\'][\'של\'][\'הפרשותיהם\', \'.\'][\'היבט\'][\'נוסף\'][\'של\'][\'חשיפת\'][\'הבנקים\'][\'לסיכוני\'][\'אשראי\'][\'ושל\'][\'היכולת\'][\'להתמודד\'][\'עם\'][\'חשיפה\'][\'זו\'][\'הוא\'][\'יחס\'][\'ההון\'][\'לנכסי\'][\'הסיכון\', \'.\'][\'יחס\'][\'זה\'][\'עלה\'][\'השנה\'][\'מעט\'][\'מכ-\'][\'9.2\', \'%\'][\'בסוף\'][\'1998\'][\'לכ-\'][\'9.4\', \'%\'][\'בסוף\'][\'1999\'][\'בין\'][\'היתר\'][\'בהשפעתה\'][\'של\'][\'הוראת\'][\'המפקח\'][\'על\'][\'הבנקים\'][\'בדבר\'][\'העלאת\'][\'יחס\'][\'ההון\'][\'המזערי\'][\'הנדרש\'][\'מ-\'][\'8\', \'%\'][\'ל-\'][\'9\', \'%\', \'.\'][\'למרות\'][\'עלייה\'][\'זו\'][\'יחס\'][\'ההון\'][\'בישראל\'][\'נמוך\'][\'מהמקובל\'][\'ברוב\'][\'המדינות\'][\'המער ...

# %%
clean = [nltk.word_tokenize(word) for word in text.split() if len(word) >2]
clean[:20]
# Out:
# [['השנה'],
#  ['הנסקרת'],
#  ['מאופיינת'],
#  ['בהתרחבות'],
#  ['ניכרת'],
#  ['פעילות'],
#  ['הבנקים', ','],
#  ['שהתבטאה'],
#  ['בעלייה'],
#  ['13', '%'],
#  ['מיצרף'],
#  ['האשראי'],
#  ['ובעלייה'],
#  ['10.5', '%'],
#  ['פיקדונות'],
#  ['הציבור'],
#  ['בבנקים', '.'],
#  ['לגידול'],
#  ['האשראי'],
#  ['תרמו']]

# %%
print ()"".)join(str(word) for word in clean)
# Out:
#   File "<ipython-input-18-b4287b3ed9e8>", line 1
#     print ("".join(str(word) for word in clean)
#                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
#clean_str = ' '.join(word for word in clean)
onegram = list(nltk.ngrams(nltk.word_tokenize(text),n=1))
bigram = list(nltk.bigrams(nltk.word_tokenize(text)))
trigram = list(nltk.trigrams(nltk.word_tokenize(text)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-fa7860a3bbc0> in <module>()
# ----> 1 clean_str = ' '.join(word for word in clean)
#       2 onegram = list(nltk.ngrams(nltk.word_tokenize(text),n=1))
#       3 bigram = list(nltk.bigrams(nltk.word_tokenize(text)))
#       4 trigram = list(nltk.trigrams(nltk.word_tokenize(text)))
#
# TypeError: sequence item 0: expected str instance, list found

# %%
trigram

# %%
tokens = nltk.word_tokenize(" ".join(text))
raw = ', '.join(' '.join((a, b)) for a, b in bigram)
def remove_punct(text):
    return re.compile(r"[^\d\W]+").findall(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b1878a0d4245> in <module>()
#       1 tokens = nltk.word_tokenize(" ".join(text))
# ----> 2 raw = ', '.join(' '.join((a, b)) for a, b in bigram)
#       3 def remove_punct(text):
#       4     return re.compile(r"[^\d\W]+").findall(text)
#
# NameError: name 'bigram' is not defined

# %%
from collections import Counter

# %%
a= remove_punct(" ".join(map(str, clean)))
Counter(a).most_common(30)
# Out:
# [('הבנקים', 23),
#  ('האשראי', 12),
#  ('ההון', 11),
#  ('הבנקאות', 10),
#  ('זאת', 7),
#  ('בישראל', 7),
#  ('מספר', 6),
#  ('בשנים', 6),
#  ('האחרונות', 6),
#  ('מערכת', 6),
#  ('יחס', 6),
#  ('השנה', 5),
#  ('העלייה', 5),
#  ('פעילות', 4),
#  ('הון', 4),
#  ('בשנת', 4),
#  ('להון', 4),
#  ('הישראלית', 4),
#  ('בין', 4),
#  ('לבנקים', 4),
#  ('בנקאות', 4),
#  ('תחומי', 4),
#  ('עלייה', 3),
#  ('ל', 3),
#  ('הפעילות', 3),
#  ('הקבוצות', 3),
#  ('לכ', 3),
#  ('במדינות', 3),
#  ('ההפרשות', 3),
#  ('לחובות', 3)]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
resp = vectorizer.fit_transform([open(file, encoding="utf8").read() for file in textfiles])

# %%
# second way:
from sklearn.feature_extraction.text import CountVectorizer
text = [open(file, encoding="utf8").read() for file in textfiles]
vetorizer = CountVectorizer()
vectorizer.fit(text)
#print (vectorizer.vocabulary_)
vector = vectorizer.transform(text)
print (vector.shape)
print (type(vector))
print (vector.toarray())

# %%
vectorizer.vocabulary_

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
vectorizer.fit(text)
#vectorizer.vocabulary_
#vectorizer.idf_
vector = vectorizer.transform([text[32]])
print(vector.shape)
print(vector.toarray())

# %%
import gensim
from gensim import corpora, models, similarities

# %%
documents = ["Human machine interface for lab abc computer applications",
              "A survey of user opinion of computer system response time",
              "The EPS user interface management system",
              "System and human system engineering testing of EPS",
              "Relation of user perceived response time to error measurement",
              "The generation of random binary unordered trees",
              "The intersection graph of paths in trees",
              "Graph minors IV Widths of trees and well quasi ordering",
              "Graph minors A survey"]
stoplist = set('for a of the and to in'.split())
texts = [[word for word in document.lower().split() if word not in stoplist] for document in documents]
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]
tfidf = models.TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]
for doc in corpus_tfidf:
    print (doc)

# %%
stopWords = {}
for doc in corpus_tfidf:
    for iWord, tf_idf in doc:
        if iWord not in topWords:
            topWords[iWord] = 0

        if tf_idf > topWords[iWord]:
            topWords[iWord] = tf_idf

for i, item in enumerate(sorted(topWords.items(), key=lambda x: x[1], reverse=True), 1):
    print("%2s: %-13s %s" % (i, dictionary[item[0]], item[1]))
    if i == 6: break

# %% [markdown]
# # sentiment analysis

# %%
#first build 2 lists of pos and neg
positive_vocab = ["מצוין", "אדיר"]
negative_vocab = ["גרוע"]
neutral_vocab = ["בסדר"]

# %%
def word_feats(words):
    return dict([(word, True) for word in words])
 
positive_features = [(word_feats(pos), 'pos') for pos in positive_vocab]
negative_features = [(word_feats(neg), 'neg') for neg in negative_vocab]
neutral_features = [(word_feats(neu), 'neu') for neu in neutral_vocab]

# %%
positive_features

# %%
positive_vocab = [ 'awesome', 'outstanding', 'fantastic', 'terrific', 'good', 'nice', 'great', ':)' ]
negative_vocab = [ 'bad', 'terrible','useless', 'hate', ':(' ]
neutral_vocab = [ 'movie','the','sound','was','is','actors','did','know','words','not' ]
def word_feats(words):
    return dict([(word, True) for word in words])
 
positive_features = [(word_feats(pos), 'pos') for pos in positive_vocab]
negative_features = [(word_feats(neg), 'neg') for neg in negative_vocab]
neutral_features = [(word_feats(neu), 'neu') for neu in neutral_vocab]
neutral_features

# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import names
 
def word_feats(words):
    return dict([(word, True) for word in words])
 
positive_vocab = [ 'awesome', 'outstanding', 'fantastic', 'terrific', 'good', 'nice', 'great', ':)' ]
negative_vocab = [ 'bad', 'terrible','useless', 'hate', ':(' ]
neutral_vocab = [ 'movie','the','sound','was','is','actors','did','know','words','not' ]
 
positive_features = [(word_feats(pos), 'pos') for pos in positive_vocab]
negative_features = [(word_feats(neg), 'neg') for neg in negative_vocab]
neutral_features = [(word_feats(neu), 'neu') for neu in neutral_vocab]
 
train_set = negative_features + positive_features + neutral_features
 
classifier = NaiveBayesClassifier.train(train_set) 
 
# Predict
neg = 0
pos = 0
sentence = "Awesome movie, I liked it"
sentence = sentence.lower()
words = sentence.split(' ')
for word in words:
    classResult = classifier.classify( word_feats(word))
    if classResult == 'neg':
        neg = neg + 1
    if classResult == 'pos':
        pos = pos + 1
 
print('Positive: ' + str(float(pos)/len(words)))
print('Negative: ' + str(float(neg)/len(words)))

# %%
from gensim.corpora import WikiCorpus

language_code = "he"
inp = language_code+"wiki-latest-pages-articles.xml.bz2"
outp = "wiki.{}.text".format(language_code)
i = 0

print("Starting to create wiki corpus")
output = open(outp, 'w')
space = " "
wiki = WikiCorpus(inp, lemmatize=False, dictionary={})
for text in wiki.get_texts():
  article = space.join([t.decode("utf-8") for t in text])

  output.write(article + "\n")
  i = i + 1
  if (i % 1000 == 0):
    print("Saved " + str(i) + " articles")

output.close()
print("Finished - Saved " + str(i) + " articles")
